# %%
#Is there a relationship between number of passengers, ride duration and day of the week
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np
from datetime import datetime


# Study data files
uber_path = "uber_rides_processed.csv"

# Read the uber data and the clean data
uber_data = pd.read_csv(uber_path)
uber_data = uber_data[uber_data['passenger_count'] <= 10]
uber_data = uber_data[uber_data['year'] != 2008]
uber_data = uber_data[uber_data['fare_amount'] >= 5]
uber_data.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1         11.5        -73.965937        40.770992         -73.977657
# 2          9.5        -74.007496        40.725907         -73.987605
# 4          5.0        -73.982117        40.773972         -73.984437
# 5          9.0        -73.961419        40.801307         -73.954290
#
#    dropoff_latitude  passenger_count        date      time  day  month  year
# 0         40.723217                1  2015-05-07  15:52:06    7      5  2015
# 1         40.762827                1  2014-10-23  05:05:47   23     10  2014
# 2         40.738403                1  2013-02-28  08:32:27   28      2  2013
# 4         40.761082                1  2012-10-22  17:52:00   22     10  2012
# 5         40.778945                1  2013-01-21  13:11:32   21      1  2013

# %%
uber_data.value_counts('passenger_count')
# Out:
# passenger_count
# 1    116596
# 2     25213
# 5     11806
# 3      7640
# 6      3820
# 4      3706
# Name: count, dtype: int64

# %%
uber_data['DateTime_str'] = uber_data['date'].astype(str) + " " + uber_data['time'].astype(str)
uber_data.dtypes
# Out:
# fare_amount          float64
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# date                  object
# time                  object
# day                    int64
# month                  int64
# year                   int64
# DateTime_str          object
# dtype: object

# %%
uber_data.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1         11.5        -73.965937        40.770992         -73.977657
# 2          9.5        -74.007496        40.725907         -73.987605
# 4          5.0        -73.982117        40.773972         -73.984437
# 5          9.0        -73.961419        40.801307         -73.954290
#
#    dropoff_latitude  passenger_count        date      time  day  month  year  \
# 0         40.723217                1  2015-05-07  15:52:06    7      5  2015
# 1         40.762827                1  2014-10-23  05:05:47   23     10  2014
# 2         40.738403                1  2013-02-28  08:32:27   28      2  2013
# 4         40.761082                1  2012-10-22  17:52:00   22     10  2012
# 5         40.778945                1  2013-01-21  13:11:32   21      1  2013
#
#           DateTime_str
# 0  2015-05-07 15:52:06
# 1  2014-10-23 05:05:47
# 2  2013-02-28 08:32:27
# 4  2012-10-22 17:52:00
# 5  2013-01-21 13:11:32

# %%
date_format = '%Y-%m-%d %H:%M:%S'
uber_data['DateTime'] = datetime.today().strftime(date_format)
uber_data.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1         11.5        -73.965937        40.770992         -73.977657
# 2          9.5        -74.007496        40.725907         -73.987605
# 4          5.0        -73.982117        40.773972         -73.984437
# 5          9.0        -73.961419        40.801307         -73.954290
#
#    dropoff_latitude  passenger_count        date      time  day  month  year  \
# 0         40.723217                1  2015-05-07  15:52:06    7      5  2015
# 1         40.762827                1  2014-10-23  05:05:47   23     10  2014
# 2         40.738403                1  2013-02-28  08:32:27   28      2  2013
# 4         40.761082                1  2012-10-22  17:52:00   22     10  2012
# 5         40.778945                1  2013-01-21  13:11:32   21      1  2013
#
#           DateTime_str             DateTime
# 0  2015-05-07 15:52:06  2023-11-16 06:52:10
# 1  2014-10-23 05:05:47  2023-11-16 06:52:10
# 2  2013-02-28 08:32:27  2023-11-16 06:52:10
# 4  2012-10-22 17:52:00  2023-11-16 06:52:10
# 5  2013-01-21 13:11:32  2023-11-16 06:52:10

# %%
uber_data['DateTime'] = pd.to_datetime(uber_data['DateTime_str'])
uber_data['Day_name'] = uber_data['DateTime'].dt.day_name()
uber_data.dtypes
# Out:
# fare_amount                 float64
# pickup_longitude            float64
# pickup_latitude             float64
# dropoff_longitude           float64
# dropoff_latitude            float64
# passenger_count               int64
# date                         object
# time                         object
# day                           int64
# month                         int64
# year                          int64
# DateTime_str                 object
# DateTime             datetime64[ns]
# Day_name                     object
# dtype: object

# %%
uber_data.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1         11.5        -73.965937        40.770992         -73.977657
# 2          9.5        -74.007496        40.725907         -73.987605
# 4          5.0        -73.982117        40.773972         -73.984437
# 5          9.0        -73.961419        40.801307         -73.954290
#
#    dropoff_latitude  passenger_count        date      time  day  month  year  \
# 0         40.723217                1  2015-05-07  15:52:06    7      5  2015
# 1         40.762827                1  2014-10-23  05:05:47   23     10  2014
# 2         40.738403                1  2013-02-28  08:32:27   28      2  2013
# 4         40.761082                1  2012-10-22  17:52:00   22     10  2012
# 5         40.778945                1  2013-01-21  13:11:32   21      1  2013
#
#           DateTime_str            DateTime  Day_name
# 0  2015-05-07 15:52:06 2015-05-07 15:52:06  Thursday
# 1  2014-10-23 05:05:47 2014-10-23 05:05:47  Thursday
# 2  2013-02-28 08:32:27 2013-02-28 08:32:27  Thursday
# 4  2012-10-22 17:52:00 2012-10-22 17:52:00    Monday
# 5  2013-01-21 13:11:32 2013-01-21 13:11:32    Monday

# %%
def time_range(time):
    hour = datetime.strptime(time, date_format).hour
    if hour > 20:
        return "Night"
    elif hour > 16:
        return "Evening"
    elif hour > 12:
        return "Afternoon"
    elif hour > 8:
        return "Morning"
    elif hour > 4:
        return "EarlyMorning"
    else:
        return "Midnight"

# %%
uber_data['time_of_the_day'] = uber_data.DateTime_str.apply(lambda time: time_range(time))
uber_data.drop(['DateTime_str'], inplace=True, axis=1)
uber_data.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1         11.5        -73.965937        40.770992         -73.977657
# 2          9.5        -74.007496        40.725907         -73.987605
# 4          5.0        -73.982117        40.773972         -73.984437
# 5          9.0        -73.961419        40.801307         -73.954290
#
#    dropoff_latitude  passenger_count        date      time  day  month  year  \
# 0         40.723217                1  2015-05-07  15:52:06    7      5  2015
# 1         40.762827                1  2014-10-23  05:05:47   23     10  2014
# 2         40.738403                1  2013-02-28  08:32:27   28      2  2013
# 4         40.761082                1  2012-10-22  17:52:00   22     10  2012
# 5         40.778945                1  2013-01-21  13:11:32   21      1  2013
#
#              DateTime  Day_name time_of_the_day
# 0 2015-05-07 15:52:06  Thursday       Afternoon
# 1 2014-10-23 05:05:47  Thursday    EarlyMorning
# 2 2013-02-28 08:32:27  Thursday    EarlyMorning
# 4 2012-10-22 17:52:00    Monday         Evening
# 5 2013-01-21 13:11:32    Monday       Afternoon

# %%
# Separate DF for single passenger and multiple passengers
df_single = uber_data[uber_data['passenger_count'] == 1]
df_single.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1         11.5        -73.965937        40.770992         -73.977657
# 2          9.5        -74.007496        40.725907         -73.987605
# 4          5.0        -73.982117        40.773972         -73.984437
# 5          9.0        -73.961419        40.801307         -73.954290
#
#    dropoff_latitude  passenger_count        date      time  day  month  year  \
# 0         40.723217                1  2015-05-07  15:52:06    7      5  2015
# 1         40.762827                1  2014-10-23  05:05:47   23     10  2014
# 2         40.738403                1  2013-02-28  08:32:27   28      2  2013
# 4         40.761082                1  2012-10-22  17:52:00   22     10  2012
# 5         40.778945                1  2013-01-21  13:11:32   21      1  2013
#
#              DateTime  Day_name time_of_the_day
# 0 2015-05-07 15:52:06  Thursday       Afternoon
# 1 2014-10-23 05:05:47  Thursday    EarlyMorning
# 2 2013-02-28 08:32:27  Thursday    EarlyMorning
# 4 2012-10-22 17:52:00    Monday         Evening
# 5 2013-01-21 13:11:32    Monday       Afternoon

# %%
df_single.value_counts('year')
# Out:
# year
# 2013    19675
# 2012    18984
# 2014    18864
# 2011    17353
# 2009    16570
# 2010    16383
# 2015     8767
# Name: count, dtype: int64

# %%
g_single = pd.DataFrame(df_single.groupby(['year', 'Day_name']).count())
g_single.reset_index(inplace = True)
g_single.drop(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'date', 'time', 'day', 'month', 'DateTime', 'time_of_the_day'], inplace=True, axis=1)
g_single = g_single.rename(columns={"fare_amount": "No_of_rides"})
g_single.head()
# Out:
#    year  Day_name  No_of_rides
# 0  2009    Friday         2733
# 1  2009    Monday         2095
# 2  2009  Saturday         2217
# 3  2009    Sunday         1630
# 4  2009  Thursday         2807

# %%
X = ['Monday','Tuesday','Wednesday','Thursday', 'Friday', 'Saturday', 'Sunday'] 

Y_2009 = g_single.loc[g_single['year'] == 2009]
Y_2009.set_index('Day_name', inplace=True)
y_axis_2009 = Y_2009['No_of_rides'].to_list()

Y_2010 = g_single.loc[g_single['year'] == 2010]
Y_2010.set_index('Day_name', inplace=True)
y_axis_2010 = Y_2010['No_of_rides'].to_list()

Y_2011 = g_single.loc[g_single['year'] == 2011]
Y_2011.set_index('Day_name', inplace=True)
y_axis_2011 = Y_2011['No_of_rides'].to_list()

Y_2012 = g_single.loc[g_single['year'] == 2012]
Y_2012.set_index('Day_name', inplace=True)
y_axis_2012 = Y_2012['No_of_rides'].to_list()

Y_2013 = g_single.loc[g_single['year'] == 2013]
Y_2013.set_index('Day_name', inplace=True)
y_axis_2013 = Y_2013['No_of_rides'].to_list()

Y_2014 = g_single.loc[g_single['year'] == 2014]
Y_2014.set_index('Day_name', inplace=True)
y_axis_2014 = Y_2014['No_of_rides'].to_list()

Y_2015 = g_single.loc[g_single['year'] == 2015]
Y_2015.set_index('Day_name', inplace=True)
y_axis_2015 = Y_2015['No_of_rides'].to_list()

x = np.arange(len(X))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots(layout='constrained')

plt.bar(x, y_axis_2009, 0.1, label = '2009') 
plt.bar(x + 0.1, y_axis_2010, 0.1, label = '2010') 
plt.bar(x + 0.2, y_axis_2011, 0.1, label = '2011') 
plt.bar(x + 0.3, y_axis_2012, 0.1, label = '2012') 
plt.bar(x + 0.4, y_axis_2013, 0.1, label = '2013') 
plt.bar(x + 0.5, y_axis_2014, 0.1, label = '2014') 
plt.bar(x + 0.6, y_axis_2015, 0.1, label = '2015') 
  
plt.xticks(x, X, rotation='vertical') 
plt.xlabel("day of week") 
plt.ylabel("Number of rides") 
plt.title("Day of week vs no of single passenger rides") 

pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.85])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
plt.show()

# %%
# Single passenger numbers over months
g_single = pd.DataFrame(df_single.groupby(['year', 'month']).count())
g_single.reset_index(inplace = True)
g_single.drop(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'date', 'time', 'day', 'Day_name', 'DateTime'], inplace=True, axis=1)
g_single = g_single.rename(columns={"fare_amount": "No_of_rides"})
g_single.head()
# Out:
#    year  month  No_of_rides  time_of_the_day
# 0  2009      1         1378             1378
# 1  2009      2         1257             1257
# 2  2009      3         1512             1512
# 3  2009      4         1470             1470
# 4  2009      5         1390             1390

# %%
X = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] 

Y_2009 = g_single.loc[g_single['year'] == 2009]
Y_2009.set_index('month', inplace=True)
y_axis_2009 = Y_2009['No_of_rides'].to_list()

Y_2010 = g_single.loc[g_single['year'] == 2010]
Y_2010.set_index('month', inplace=True)
y_axis_2010 = Y_2010['No_of_rides'].to_list()

Y_2011 = g_single.loc[g_single['year'] == 2011]
Y_2011.set_index('month', inplace=True)
y_axis_2011 = Y_2011['No_of_rides'].to_list()

Y_2012 = g_single.loc[g_single['year'] == 2012]
Y_2012.set_index('month', inplace=True)
y_axis_2012 = Y_2012['No_of_rides'].to_list()

Y_2013 = g_single.loc[g_single['year'] == 2013]
Y_2013.set_index('month', inplace=True)
y_axis_2013 = Y_2013['No_of_rides'].to_list()

Y_2014 = g_single.loc[g_single['year'] == 2014]
Y_2014.set_index('month', inplace=True)
y_axis_2014 = Y_2014['No_of_rides'].to_list()

Y_2015 = g_single.loc[g_single['year'] == 2015]
Y_2015.set_index('month', inplace=True)
y_axis_2015 = Y_2015['No_of_rides'].to_list()

x = np.arange(len(X))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots(layout='constrained')

plt.bar(x, y_axis_2009, 0.1, label = '2009') 
plt.bar(x + 0.1, y_axis_2010, 0.1, label = '2010') 
plt.bar(x + 0.2, y_axis_2011, 0.1, label = '2011') 
plt.bar(x + 0.3, y_axis_2012, 0.1, label = '2012') 
plt.bar(x + 0.4, y_axis_2013, 0.1, label = '2013') 
plt.bar(x + 0.5, y_axis_2014, 0.1, label = '2014') 

#Exclude 2015 
#plt.bar(x + 0.48, y_axis_2015, 0.08, label = '2015') 
  
plt.xticks(x, X, rotation='vertical') 
plt.xlabel("Month") 
plt.ylabel("Number of rides") 
plt.title("Month vs no of single passenger rides") 

pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.85])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
plt.show()

# %%
# Repeat for rides with more than one passenger
df_share = uber_data[uber_data['passenger_count'] > 1]
df_share.head()
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 135635          5.3        -74.005498        40.739775         -73.997220
# 135636          5.3        -73.979303        40.784958         -73.973257
# 135637         13.0        -73.996039        40.724246         -73.968075
# 135638         10.1        -73.977315        40.779467         -73.989473
# 135639         16.1        -73.988348        40.764157         -74.014053
#
#         dropoff_latitude  passenger_count        date      time  day  month  \
# 135635         40.732645                2  2010-02-13  21:55:46   13      2
# 135636         40.793523                2  2009-04-04  18:59:00    4      4
# 135637         40.760014                2  2014-12-13  20:07:42   13     12
# 135638         40.752282                2  2010-02-17  03:35:00   17      2
# 135639         40.702428                2  2009-01-09  12:25:00    9      1
#
#         year            DateTime   Day_name time_of_the_day
# 135635  2010 2010-02-13 21:55:46   Saturday           Night
# 135636  2009 2009-04-04 18:59:00   Saturday         Evening
# 135637  2014 2014-12-13 20:07:42   Saturday         Evening
# 135638  2010 2010-02-17 03:35:00  Wednesday        Midnight
# 135639  2009 2009-01-09 12:25:00     Friday         Morning

# %%
df_share.value_counts('year')
# Out:
# year
# 2013    8503
# 2011    8172
# 2014    8109
# 2012    8061
# 2009    8018
# 2010    7641
# 2015    3681
# Name: count, dtype: int64

# %%
g_share = pd.DataFrame(df_share.groupby(['year', 'Day_name']).count())
g_share.reset_index(inplace = True)
g_share.drop(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'date', 'time', 'day', 'month', 'DateTime', 'time_of_the_day'], inplace=True, axis=1)
g_share = g_share.rename(columns={"fare_amount": "No_of_rides"})
g_share.head()
# Out:
#    year  Day_name  No_of_rides
# 0  2009    Friday         1448
# 1  2009    Monday          879
# 2  2009  Saturday         1490
# 3  2009    Sunday          944
# 4  2009  Thursday         1176

# %%
X = ['Monday','Tuesday','Wednesday','Thursday', 'Friday', 'Saturday', 'Sunday'] 

Y_2009 = g_share.loc[g_share['year'] == 2009]
Y_2009.set_index('Day_name', inplace=True)
y_axis_2009 = Y_2009['No_of_rides'].to_list()

Y_2010 = g_share.loc[g_share['year'] == 2010]
Y_2010.set_index('Day_name', inplace=True)
y_axis_2010 = Y_2010['No_of_rides'].to_list()

Y_2011 = g_share.loc[g_share['year'] == 2011]
Y_2011.set_index('Day_name', inplace=True)
y_axis_2011 = Y_2011['No_of_rides'].to_list()

Y_2012 = g_share.loc[g_share['year'] == 2012]
Y_2012.set_index('Day_name', inplace=True)
y_axis_2012 = Y_2012['No_of_rides'].to_list()

Y_2013 = g_share.loc[g_share['year'] == 2013]
Y_2013.set_index('Day_name', inplace=True)
y_axis_2013 = Y_2013['No_of_rides'].to_list()

Y_2014 = g_share.loc[g_share['year'] == 2014]
Y_2014.set_index('Day_name', inplace=True)
y_axis_2014 = Y_2014['No_of_rides'].to_list()

Y_2015 = g_share.loc[g_share['year'] == 2015]
Y_2015.set_index('Day_name', inplace=True)
y_axis_2015 = Y_2015['No_of_rides'].to_list()

x = np.arange(len(X))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots(layout='constrained')

plt.bar(x, y_axis_2009, 0.1, label = '2009') 
plt.bar(x + 0.1, y_axis_2010, 0.1, label = '2010') 
plt.bar(x + 0.2, y_axis_2011, 0.1, label = '2011') 
plt.bar(x + 0.3, y_axis_2012, 0.1, label = '2012') 
plt.bar(x + 0.4, y_axis_2013, 0.1, label = '2013') 
plt.bar(x + 0.5, y_axis_2014, 0.1, label = '2014') 
plt.bar(x + 0.6, y_axis_2015, 0.1, label = '2015') 
  
plt.xticks(x, X, rotation='vertical') 
plt.xlabel("day of week") 
plt.ylabel("Number of rides") 
plt.title("Day of week vs no of shared rides") 

pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.85])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
plt.show()

# %%
g_share = pd.DataFrame(df_share.groupby(['year', 'month']).count())
g_share.reset_index(inplace = True)
g_share.drop(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'date', 'time', 'day', 'Day_name', 'DateTime', 'time_of_the_day'], inplace=True, axis=1)
g_share = g_share.rename(columns={"fare_amount": "No_of_rides"})
g_share.head()
# Out:
#    year  month  No_of_rides
# 0  2009      1          686
# 1  2009      2          604
# 2  2009      3          685
# 3  2009      4          634
# 4  2009      5          715

# %%
X = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] 

Y_2009 = g_share.loc[g_share['year'] == 2009]
Y_2009.set_index('month', inplace=True)
y_axis_2009 = Y_2009['No_of_rides'].to_list()

Y_2010 = g_share.loc[g_share['year'] == 2010]
Y_2010.set_index('month', inplace=True)
y_axis_2010 = Y_2010['No_of_rides'].to_list()

Y_2011 = g_share.loc[g_share['year'] == 2011]
Y_2011.set_index('month', inplace=True)
y_axis_2011 = Y_2011['No_of_rides'].to_list()

Y_2012 = g_share.loc[g_share['year'] == 2012]
Y_2012.set_index('month', inplace=True)
y_axis_2012 = Y_2012['No_of_rides'].to_list()

Y_2013 = g_share.loc[g_share['year'] == 2013]
Y_2013.set_index('month', inplace=True)
y_axis_2013 = Y_2013['No_of_rides'].to_list()

Y_2014 = g_share.loc[g_share['year'] == 2014]
Y_2014.set_index('month', inplace=True)
y_axis_2014 = Y_2014['No_of_rides'].to_list()

Y_2015 = g_share.loc[g_share['year'] == 2015]
Y_2015.set_index('month', inplace=True)
y_axis_2015 = Y_2015['No_of_rides'].to_list()

x = np.arange(len(X))  # the label locations
width = 0.08  # the width of the bars

fig, ax = plt.subplots(layout='constrained')

plt.bar(x, y_axis_2009, 0.08, label = '2009') 
plt.bar(x + 0.1, y_axis_2010, 0.08, label = '2010') 
plt.bar(x + 0.2, y_axis_2011, 0.08, label = '2011') 
plt.bar(x + 0.3, y_axis_2012, 0.08, label = '2012') 
plt.bar(x + 0.4, y_axis_2013, 0.08, label = '2013') 
plt.bar(x + 0.5, y_axis_2014, 0.08, label = '2014') 

#Exclude 2015 
#plt.bar(x + 0.6, y_axis_2015, 0.08, label = '2015') 
  
plt.xticks(x, X, rotation='vertical') 
plt.xlabel("Month") 
plt.ylabel("Number of rides") 
plt.title("Month vs no of shared rides") 

pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.85])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
plt.show()

# %%
# Analyse no of single passenger rides vs time of the for year 2013
df_2013_1 = uber_data[(uber_data['year'] == 2013) &
                      (uber_data['passenger_count'] == 1)]
df_2013_1
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 2               9.5        -74.007496        40.725907         -73.987605
# 5               9.0        -73.961419        40.801307         -73.954290
# 13              7.5        -74.001544        40.741133         -73.987411
# 20             12.5        -74.007105        40.711864         -73.989167
# 27             10.0        -73.984972        40.736967         -73.965872
# ...             ...               ...              ...                ...
# 135617          6.0        -73.979517        40.765270         -73.972537
# 135622          8.5        -73.993309        40.752515         -73.976738
# 135623         11.0        -73.978252        40.734337         -74.003552
# 135627         10.0        -73.971340        40.751617         -74.002162
# 135634          5.5        -73.972208        40.786287         -73.978900
#
#         dropoff_latitude  passenger_count        date      time  day  month  \
# 2              40.738403                1  2013-02-28  08:32:27   28      2
# 5              40.778945                1  2013-01-21  13:11:32   21      1
# 13             40.765251                1  2013-02-21  21:00:52   21      2
# 20             40.725543                1  2013-06-23  13:08:16   23      6
# 27             40.762695                1  2013-10-23  17:58:00   23     10
# ...                  ...              ...         ...       ...  ...    ...
# 135617         40.757682                1  2013-06-28  16:45:00   28      6
# 135622         40.756135                1  2013-03-07  12:34:54    7      3
# 135623         40.750700                1  2013-06-29  19:15:00   29      6
# 135627         40.725832                1  2013-12-08  03:22:00    8     12
# 135634         40.778377                1  2013-08-16  06:47:00   16      8
#
#         year            DateTime   Day_name time_of_the_day
# 2       2013 2013-02-28 08:32:27   Thursday    EarlyMorning
# 5       2013 2013-01-21 13:11:32     Monday       Afternoon
# 13      2013 2013-02-21 21:00:52   Thursday           Night
# 20      2013 2013-06-23 13:08:16     Sunday       Afternoon
# 27      2013 2013-10-23 17:58:00  Wednesday         Evening
# ...      ...                 ...        ...             ...
# 135617  2013 2013-06-28 16:45:00     Friday       Afternoon
# 135622  2013 2013-03-07 12:34:54   Thursday         Morning
# 135623  2013 2013-06-29 19:15:00   Saturday         Evening
# 135627  2013 2013-12-08 03:22:00     Sunday        Midnight
# 135634  2013 2013-08-16 06:47:00     Friday    EarlyMorning
#
# [19675 rows x 14 columns]

# %%
df_2013_1.value_counts('passenger_count')
# Out:
# passenger_count
# 1    19675
# Name: count, dtype: int64

# %%
g_single = pd.DataFrame(df_2013_1.groupby(['Day_name', 'time_of_the_day']).count())
g_single.reset_index(inplace = True)
g_single.drop(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'date', 'time', 'day', 'month', 'year', 'DateTime'], inplace=True, axis=1)
g_single = g_single.rename(columns={"fare_amount": "No_of_rides"})
g_single
# Out:
#      Day_name time_of_the_day  No_of_rides
# 0      Friday       Afternoon          649
# 1      Friday    EarlyMorning          618
# 2      Friday         Evening          646
# 3      Friday        Midnight          510
# 4      Friday         Morning          552
# 5      Friday           Night          279
# 6      Monday       Afternoon          654
# 7      Monday    EarlyMorning          540
# 8      Monday         Evening          395
# 9      Monday        Midnight          447
# 10     Monday         Morning          503
# 11     Monday           Night           72
# 12   Saturday       Afternoon          580
# 13   Saturday    EarlyMorning          473
# 14   Saturday         Evening          626
# 15   Saturday        Midnight          239
# 16   Saturday         Morning          504
# 17   Saturday           Night          316
# 18     Sunday       Afternoon          468
# 19     Sunday    EarlyMorning          450
# 20     Sunday         Evening          351
# 21     Sunday        Midnight          240
# 22     Sunday         Morning          452
# 23     Sunday           Night           74
# 24   Thursday       Afternoon          722
# 25   Thursday    EarlyMorning          585
# 26   Thursday         Evening          621
# 27   Thursday        Midnight          537
# 28   Thursday         Morning          543
# 29   Thursday           Night          143
# 30    Tuesday       Afternoon          700
# 31    Tuesday    EarlyMorning          539
# 32    Tuesday         Evening          491
# 33    Tuesday        Midnight          465
# 34    Tuesday         Morning          533
# 35    Tuesday           Night           98
# 36  Wednesday       Afternoon          769
# 37  Wednesday    EarlyMorning          626
# 38  Wednesday         Evening          519
# 39  Wednesday        Midnight          503
# 40  Wednesday         Morning          526
# 41  Wednesday           Night          117

# %%
X = ['Monday','Tuesday','Wednesday','Thursday', 'Friday', 'Saturday', 'Sunday'] 

early_morning = g_single.loc[g_single['time_of_the_day'] == 'EarlyMorning']
early_morning.set_index('Day_name', inplace=True)
y1 = early_morning['No_of_rides']

morning = g_single.loc[g_single['time_of_the_day'] == 'Morning']
morning.set_index('Day_name', inplace=True)
y2 = morning['No_of_rides']

afternoon = g_single.loc[g_single['time_of_the_day'] == 'Afternoon']
afternoon.set_index('Day_name', inplace=True)
y3 = afternoon['No_of_rides']

evening = g_single.loc[g_single['time_of_the_day'] == 'Evening']
evening.set_index('Day_name', inplace=True)
y4 = evening['No_of_rides']

night = g_single.loc[g_single['time_of_the_day'] == 'Night']
night.set_index('Day_name', inplace=True)
y5 = night['No_of_rides']

evening = g_single.loc[g_single['time_of_the_day'] == 'Midnight']
evening.set_index('Day_name', inplace=True)
y6 = evening['No_of_rides']

x = np.arange(len(X))  # the label locations

fig, ax = plt.subplots(layout='constrained')
plt.bar(x, y1, label = 'Early Morning') 
plt.bar(x, y2, bottom=y1, label = 'Morning') 
plt.bar(x, y3, bottom=y1+y2, label = 'Afternoon') 
plt.bar(x, y4, bottom=y1+y2+y3, label = 'Evening') 
plt.bar(x, y5, bottom=y1+y2+y3+y4, label = 'Night') 
plt.bar(x, y6, bottom=y1+y2+y3+y4+y5, label = 'Midnight') 
  
plt.xticks(x, X, rotation='vertical') 
plt.xlabel("day of week") 
plt.ylabel("Number of rides") 
plt.title("Day of week vs no of single passenger rides - time of the day breakdown") 

pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.85])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
plt.show()

# %%
####

# %%
df_2013_2 = uber_data[(uber_data['year'] == 2013) &
                      (uber_data['passenger_count'] > 1)]
df_2013_2
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 135652          8.5        -74.005890        40.740272         -73.987925
# 135654          9.5        -73.961145        40.770102         -73.967087
# 135660         19.5        -73.953745        40.787048         -74.003938
# 135668         12.5        -73.983262        40.725910         -73.993722
# 135677         43.5        -73.965937        40.762102         -73.751795
# ...             ...               ...              ...                ...
# 195304          9.5        -73.994842        40.720635         -73.978672
# 195307          8.5        -73.963820        40.808115         -73.945297
# 195311         10.5        -74.008447        40.736457         -73.987220
# 195323          9.0        -74.003853        40.725572         -73.996612
# 195326          8.0        -74.001620        40.732312         -73.982295
#
#         dropoff_latitude  passenger_count        date      time  day  month  \
# 135652         40.744563                2  2013-05-17  17:47:21   17      5
# 135654         40.792700                2  2013-12-31  20:45:00   31     12
# 135660         40.737139                2  2013-05-03  17:24:19    3      5
# 135668         40.751462                2  2013-01-26  06:04:12   26      1
# 135677         40.768475                2  2013-05-30  19:47:00   30      5
# ...                  ...              ...         ...       ...  ...    ...
# 195304         40.744607                6  2013-10-19  23:14:00   19     10
# 195307         40.811852                6  2013-08-09  12:33:00    9      8
# 195311         40.750647                6  2013-02-19  05:29:00   19      2
# 195323         40.732452                6  2013-05-18  09:05:00   18      5
# 195326         40.745492                6  2013-02-28  20:36:00   28      2
#
#         year            DateTime  Day_name time_of_the_day
# 135652  2013 2013-05-17 17:47:21    Friday         Evening
# 135654  2013 2013-12-31 20:45:00   Tuesday         Evening
# 135660  2013 2013-05-03 17:24:19    Friday         Evening
# 135668  2013 2013-01-26 06:04:12  Saturday    EarlyMorning
# 135677  2013 2013-05-30 19:47:00  Thursday         Evening
# ...      ...                 ...       ...             ...
# 195304  2013 2013-10-19 23:14:00  Saturday           Night
# 195307  2013 2013-08-09 12:33:00    Friday         Morning
# 195311  2013 2013-02-19 05:29:00   Tuesday    EarlyMorning
# 195323  2013 2013-05-18 09:05:00  Saturday         Morning
# 195326  2013 2013-02-28 20:36:00  Thursday         Evening
#
# [8503 rows x 14 columns]

# %%
df_2013_2.value_counts('passenger_count')
# Out:
# passenger_count
# 2    3919
# 5    1613
# 3    1261
# 6    1115
# 4     595
# Name: count, dtype: int64

# %%
g_share = pd.DataFrame(df_2013_2.groupby(['Day_name', 'time_of_the_day']).count())
g_share.reset_index(inplace = True)
g_share.drop(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'date', 'time', 'day', 'month', 'year', 'DateTime'], inplace=True, axis=1)
g_share = g_share.rename(columns={"fare_amount": "No_of_rides"})
g_share
# Out:
#      Day_name time_of_the_day  No_of_rides
# 0      Friday       Afternoon          369
# 1      Friday    EarlyMorning          224
# 2      Friday         Evening          354
# 3      Friday        Midnight          136
# 4      Friday         Morning          196
# 5      Friday           Night          160
# 6      Monday       Afternoon          263
# 7      Monday    EarlyMorning          221
# 8      Monday         Evening          185
# 9      Monday        Midnight          121
# 10     Monday         Morning          212
# 11     Monday           Night           29
# 12   Saturday       Afternoon          358
# 13   Saturday    EarlyMorning          243
# 14   Saturday         Evening          394
# 15   Saturday        Midnight           89
# 16   Saturday         Morning          293
# 17   Saturday           Night          232
# 18     Sunday       Afternoon          237
# 19     Sunday    EarlyMorning          211
# 20     Sunday         Evening          172
# 21     Sunday        Midnight           90
# 22     Sunday         Morning          275
# 23     Sunday           Night           36
# 24   Thursday       Afternoon          291
# 25   Thursday    EarlyMorning          211
# 26   Thursday         Evening          272
# 27   Thursday        Midnight          171
# 28   Thursday         Morning          189
# 29   Thursday           Night           71
# 30    Tuesday       Afternoon          285
# 31    Tuesday    EarlyMorning          214
# 32    Tuesday         Evening          230
# 33    Tuesday        Midnight          127
# 34    Tuesday         Morning          226
# 35    Tuesday           Night           52
# 36  Wednesday       Afternoon          305
# 37  Wednesday    EarlyMorning          202
# 38  Wednesday         Evening          211
# 39  Wednesday        Midnight          109
# 40  Wednesday         Morning          193
# 41  Wednesday           Night           44

# %%
X = ['Monday','Tuesday','Wednesday','Thursday', 'Friday', 'Saturday', 'Sunday'] 

early_morning = g_share.loc[g_share['time_of_the_day'] == 'EarlyMorning']
early_morning.set_index('Day_name', inplace=True)
y1 = early_morning['No_of_rides']

morning = g_share.loc[g_share['time_of_the_day'] == 'Morning']
morning.set_index('Day_name', inplace=True)
y2 = morning['No_of_rides']

afternoon = g_share.loc[g_share['time_of_the_day'] == 'Afternoon']
afternoon.set_index('Day_name', inplace=True)
y3 = afternoon['No_of_rides']

evening = g_share.loc[g_share['time_of_the_day'] == 'Evening']
evening.set_index('Day_name', inplace=True)
y4 = evening['No_of_rides']

night = g_share.loc[g_share['time_of_the_day'] == 'Night']
night.set_index('Day_name', inplace=True)
y5 = night['No_of_rides']

evening = g_share.loc[g_share['time_of_the_day'] == 'Midnight']
evening.set_index('Day_name', inplace=True)
y6 = evening['No_of_rides']

x = np.arange(len(X))  # the label locations

fig, ax = plt.subplots(layout='constrained')
plt.bar(x, y1, label = 'Early Morning') 
plt.bar(x, y2, bottom=y1, label = 'Morning') 
plt.bar(x, y3, bottom=y1+y2, label = 'Afternoon') 
plt.bar(x, y4, bottom=y1+y2+y3, label = 'Evening') 
plt.bar(x, y5, bottom=y1+y2+y3+y4, label = 'Night') 
plt.bar(x, y6, bottom=y1+y2+y3+y4+y5, label = 'Midnight') 
  
plt.xticks(x, X, rotation='vertical') 
plt.xlabel("day of week") 
plt.ylabel("Number of rides") 
plt.title("Day of week vs no of shared rides - time of the day breakdown") 

pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.85])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
plt.show()

# %%
g_single = pd.DataFrame(df_2013_1.groupby(['month', 'time_of_the_day']).count())
g_single.reset_index(inplace = True)
g_single.drop(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'date', 'time', 'day', 'year', 'Day_name', 'DateTime'], inplace=True, axis=1)
g_single = g_single.rename(columns={"fare_amount": "No_of_rides"})
g_single
# Out:
#     month time_of_the_day  No_of_rides
# 0       1       Afternoon          435
# 1       1    EarlyMorning          322
# 2       1         Evening          216
# 3       1        Midnight          308
# 4       1         Morning          325
# ..    ...             ...          ...
# 67     12    EarlyMorning          298
# 68     12         Evening          265
# 69     12        Midnight          271
# 70     12         Morning          273
# 71     12           Night           91
#
# [72 rows x 3 columns]

# %%
X = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] 

early_morning = g_single.loc[g_single['time_of_the_day'] == 'EarlyMorning']
early_morning.set_index('month', inplace=True)
y1 = early_morning['No_of_rides']

morning = g_single.loc[g_single['time_of_the_day'] == 'Morning']
morning.set_index('month', inplace=True)
y2 = morning['No_of_rides']

afternoon = g_single.loc[g_single['time_of_the_day'] == 'Afternoon']
afternoon.set_index('month', inplace=True)
y3 = afternoon['No_of_rides']

evening = g_single.loc[g_single['time_of_the_day'] == 'Evening']
evening.set_index('month', inplace=True)
y4 = evening['No_of_rides']

night = g_single.loc[g_single['time_of_the_day'] == 'Night']
night.set_index('month', inplace=True)
y5 = night['No_of_rides']

evening = g_single.loc[g_single['time_of_the_day'] == 'Midnight']
evening.set_index('month', inplace=True)
y6 = evening['No_of_rides']

x = np.arange(len(X))  # the label locations

fig, ax = plt.subplots(layout='constrained')
plt.bar(x, y1, label = 'Early Morning') 
plt.bar(x, y2, bottom=y1, label = 'Morning') 
plt.bar(x, y3, bottom=y1+y2, label = 'Afternoon') 
plt.bar(x, y4, bottom=y1+y2+y3, label = 'Evening') 
plt.bar(x, y5, bottom=y1+y2+y3+y4, label = 'Night') 
plt.bar(x, y6, bottom=y1+y2+y3+y4+y5, label = 'Midnight') 
  
plt.xticks(x, X, rotation='vertical') 
plt.xlabel("Month") 
plt.ylabel("Number of rides") 
plt.title("Month vs no of single passenger rides - time of the day breakdown") 

pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.85])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
plt.show()

# %%
g_share = pd.DataFrame(df_2013_2.groupby(['month', 'time_of_the_day']).count())
g_share.reset_index(inplace = True)
g_share.drop(['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'date', 'time', 'day', 'year', 'Day_name', 'DateTime'], inplace=True, axis=1)
g_share = g_share.rename(columns={"fare_amount": "No_of_rides"})
g_share
# Out:
#     month time_of_the_day  No_of_rides
# 0       1       Afternoon          172
# 1       1    EarlyMorning          135
# 2       1         Evening          132
# 3       1        Midnight           81
# 4       1         Morning          126
# ..    ...             ...          ...
# 67     12    EarlyMorning          142
# 68     12         Evening          145
# 69     12        Midnight           81
# 70     12         Morning          151
# 71     12           Night           51
#
# [72 rows x 3 columns]

# %%
X = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] 

early_morning = g_share.loc[g_share['time_of_the_day'] == 'EarlyMorning']
early_morning.set_index('month', inplace=True)
y1 = early_morning['No_of_rides']

morning = g_share.loc[g_share['time_of_the_day'] == 'Morning']
morning.set_index('month', inplace=True)
y2 = morning['No_of_rides']

afternoon = g_share.loc[g_share['time_of_the_day'] == 'Afternoon']
afternoon.set_index('month', inplace=True)
y3 = afternoon['No_of_rides']

evening = g_share.loc[g_share['time_of_the_day'] == 'Evening']
evening.set_index('month', inplace=True)
y4 = evening['No_of_rides']

night = g_share.loc[g_share['time_of_the_day'] == 'Night']
night.set_index('month', inplace=True)
y5 = night['No_of_rides']

evening = g_share.loc[g_share['time_of_the_day'] == 'Midnight']
evening.set_index('month', inplace=True)
y6 = evening['No_of_rides']

x = np.arange(len(X))  # the label locations

fig, ax = plt.subplots(layout='constrained')
plt.bar(x, y1, label = 'Early Morning') 
plt.bar(x, y2, bottom=y1, label = 'Morning') 
plt.bar(x, y3, bottom=y1+y2, label = 'Afternoon') 
plt.bar(x, y4, bottom=y1+y2+y3, label = 'Evening') 
plt.bar(x, y5, bottom=y1+y2+y3+y4, label = 'Night') 
plt.bar(x, y6, bottom=y1+y2+y3+y4+y5, label = 'Midnight') 
  
plt.xticks(x, X, rotation='vertical') 
plt.xlabel("Month") 
plt.ylabel("Number of rides") 
plt.title("Month vs no of shared rides - time of the day breakdown") 

pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width, pos.height * 0.85])
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, 1.35),
    ncol=3, 
)
plt.show()
